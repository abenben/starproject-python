# %% [markdown]
# <a href="https://colab.research.google.com/github/abenben/starproject-python/blob/master/slide09-base/mathplot-01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 2.1: グラフの描画

# %%
# 2.1.1　matplotlib.pyplot モジュールのインポート

import matplotlib.pyplot as plt

# %%
# 2.1.2　ノートブック上に Matplotlib のグラフを出力するためのマジックコマンド

# %matplotlib inline

# %%
# 2.1.3　図を描画（インライン表示）

# 図を描画（インライン表示）

fig, ax = plt.subplots(1, 1)
ax.plot([0, 1])

# %%
# 2.1.4　add_axes() メソッドでサブプロットを配置

fig = plt.figure(linewidth=5, edgecolor="k")

# left, bottom, width, height
rect1 = 0.2, 0.2, 0.3, 0.3
rect2 = 0.5, 0.5, 0.4, 0.4

# サブプロットオブジェクトを配置
ax1 = fig.add_axes(rect1)
ax2 = fig.add_axes(rect2)
fig.savefig("add_axes.png", linewidth=5, edgecolor="k")

# %%
# 2.1.5　出力した図をノートブック上に表示

from IPython.display import Image

Image("add_axes.png")

# %%
# 2.1.6　add_subplots() メソッドによるサブプロットの配置

# フィギュアオブジェクトの生成
fig = plt.figure()

# フィギュア内にサブプロットを3つ配置
ax1 = fig.add_subplot(2, 2, 1)  # 2行2列の1番
ax2 = fig.add_subplot(2, 2, 2)  # 2行2列の2番
ax3 = fig.add_subplot(2, 2, 3)  # 2行2列の3番

# サブプロット名とサブプロット番号をサブプロット内に描画
for i, ax in enumerate([ax1, ax2, ax3], start=1):
    txt = f"ax{i}\n(2, 2, {i})"
    ax.text(0.2, 0.5, txt)

# %%
# 2.1.7　subplots() メソッドによるサブプロットの配置

import itertools

# フィギュアオブジェクトの生成
fig = plt.figure()

# subplots()による2行3列のサブプロットオブジェクトの生成
lines, columns = 2, 3
axes = fig.subplots(lines, columns)

# サブプロットの位置をサブプロット内に描画
# 行番号を「l」、列番号を「c」で指定
for l, c in itertools.product(range(lines), range(columns)):
    axes[l, c].text(0.1, 0.5, f"axes[{l}, {c}]")

# %%
# 2.1.8　axes インスタンスに格納された値を確認

axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9f54fce940>,
# ...
#       dtype=object)

# %%
# 2.1.9　pyplot.subplots() でサブプロットを配置

fig, axes = plt.subplots(2, 2)
