# %% [markdown]
# <a href="https://colab.research.google.com/github/abenben/starproject-python/blob/master/slide09-base/seaborn-02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 3.2: グラフの描画方法

# %%
# 3.2.1　tips データセットの読み込み

import seaborn as sns

tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 3.2.2　scatterplot() 関数による散布図の描画

sns.scatterplot(data=tips, x="total_bill", y="tip")

# %%
# 3.2.3　Matplotlib で配置やグラフタイトルを設定

import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
sns.scatterplot(data=tips, x="total_bill", y="tip", ax=ax1)
sns.scatterplot(data=tips, x="size", y="tip", ax=ax2)
ax1.set_title("totall bill and tips")
ax2.set_title("size and tips")
# Out:
# Text(0.5, 1.0, 'size and tips')

# %%
# 3.2.4　散布図とヒストグラムを並べて描画

sns.jointplot(data=tips, x="total_bill", y="tip")

# %%
# 3.2.5　smoker 列でデータを分割して描画

sns.relplot(data=tips, x="total_bill", y="tip", row="smoker")

# %%
# 3.2.6　time 列でデータを分割して描画

sns.relplot(data=tips, x="total_bill", y="tip", col="time")

# %%
# 3.2.7　smoker 列と time 列でデータを分割して描画

sns.relplot(data=tips, x="total_bill", y="tip", row="smoker", col="time")

# %%
# 3.2.8　pairplot() 関数を用いて散布図行列を描画

sns.pairplot(data=tips, vars=["total_bill", "tip", "size"])

# %%
# 3.2.9　雑然データの DataFrame を作成

import pandas as pd

wide_df = pd.DataFrame(
    [["Tokyo", 5.8, 5.7, 5.6], ["Osaka", 6.8, 6.7, 6.6], ["Nagoya", 5.1, 5.1, 5.0],],
    columns=["Location", "2020-01-01", "2020-01-02", "2020-01-03"],
)
wide_df
# Out:
#   Location  2020-01-01  2020-01-02  2020-01-03
# 0    Tokyo         5.8         5.7         5.6
# 1    Osaka         6.8         6.7         6.6
# 2   Nagoya         5.1         5.1         5.0

# %%
# 3.2.10　melt メソッドによる整然データへの変換

tidy_df = wide_df.melt(id_vars="Location", var_name="Date", value_name="Temperature")
tidy_df
# Out:
#   Location        Date  Temperature
# 0    Tokyo  2020-01-01          5.8
# 1    Osaka  2020-01-01          6.8
# 2   Nagoya  2020-01-01          5.1
# 3    Tokyo  2020-01-02          5.7
# 4    Osaka  2020-01-02          6.7
# 5   Nagoya  2020-01-02          5.1
# 6    Tokyo  2020-01-03          5.6
# 7    Osaka  2020-01-03          6.6
# 8   Nagoya  2020-01-03          5.0

# %%
# 3.2.11　catplot() 関数を利用した棒グラフの描画

sns.catplot(data=tidy_df, x="Date", y="Temperature", kind="bar", hue="Location")
