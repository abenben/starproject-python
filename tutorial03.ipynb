# %% [markdown]
# <a href="https://colab.research.google.com/github/abenben/starproject-python/blob/master/tutorial03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Python基礎講座（２日目）**
#
#  # 前回の復習
#
# 基本的なデータの型の種類を理解しよう。
#
# 前回の復習を兼ねて基本的なデータの型の種類と、複数のデータ型をひとまとめにして扱えるコレクションについておさらいをしまよう。

# %% [markdown]
# # 1.Pythonのデータ型（基本編）
#
# 代表的なPythonのデータ型と、便利な使い方を紹介します。
#
# それぞれのデータ型の紹介で、「これだけは知っておくとよいよ」という機能を挙げます。

# %% [markdown]
# ## 1.1. はじめに
#
# 本節では整数型（int）、浮動小数点型（float）、文字列型（str）を扱います。
#
# データ型については、Pythonの公式ドキュメントも参考にしてください。
#
# 組み込み型 https://docs.python.org/ja/3/library/stdtypes.html

# %% [markdown]
# ## 1.2. 整数型（int）
#
# 整数を扱うには、整数型（int）を使います。
#
# 主な演算子には、前節で説明した四則演算（+、-、*、/）と剰余（%）の他に、累乗（**）があります

# %% [markdown]
# ### 整数型
# ```
# ▶ 2+1
# 4
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 3 - 8
# -5
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 6 * 9
# 54
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 8 / 2
# 4.0
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 5 % 2
# 1
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 5 ** 2
# 25
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### 整数型同士の商
#
# 割り算の結果は小数点以下も出力されます

# %% [markdown]
# ```
# ▶ 10 / 3
# 3.3333333333333335
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 10 / 4
# 2.5
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ -10 / 4
# -2.5
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### //での割り算
#
# 割り算の結果を整数で取得したい場合は // 演算子を使用します。 その場合は、小数点以下は切り捨てられます。

# %% [markdown]
# ```
# ▶ 10 // 3
# 3
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 10 // 4
# 2
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ -10 // 4
# -3
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ## 1.3. 浮動小数点型（float）

# %% [markdown]
# ### 浮動小数点の計算
#
# 小数を扱うには浮動小数点型（float）を使います。
#
# 整数型と同様の演算子が使えます。
#
# 浮動小数点型と整数型との計算は浮動小数点型を返します。

# %% [markdown]
# ```
# ▶ 5.0
# 5.0
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 5.0 + 5.2
# 10.2
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 10.2 + 8
# 18.2
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ## 1.4. 文字列型（str）
#
# 文字列を使うには文字列型（str）を使います。
# シングルクォート（'）かダブルクォート（"）の間に文字を入力します。 シングルクォート、ダブルクォートのどちらで書いても機能的な違いはありません。
# ```
# ▶ 'Hello,world'
# 'Hello,world'
# ▶ "Hello,world"
# 'Hello,world'
# ```

# %% [markdown]
# ### 1.4.1. 文字のエスケープ
#
# 文字列中にクォート文字やその他の特殊な文字を含めたい場合は、バックスラッシュ（\）でエスケープします。
#
# たとえば、シングルクォートで囲まれた文字列中では、シングルクォートを \' と書き、改行文字を \n と書きます

# %% [markdown]
# ```
# ▶ print('I\'m Kazuya')
# I'm Kazuya Kazuya
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ print('Hello\nworld')
# Hello
# world
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# **シングルクォートを含む文字列について**
#
# 文字列がシングルクォートを含み、ダブルクォートを含まない場合は、ダブルクォートで囲むと見やすいです。
#
# ```
# ▶ print("I'm Kazuya")
# I'm Kazuya
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### 1.4.2. 三重クォート
#
# 改行を含む文字列を一度に定義するには、三重クォート（クォート文字3つ）で文字列を囲みます。
#
# シングルクォートの場合は ''' 、ダブルクォートの場合は """ です
#
# ```
# ▶ """ foo
# ▶ bar
# ▶ baz
# ▶ """
# ' foo\nbar\nbaz\n'
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### 1.4.3. 文字列の結合と繰り返し
#
# 文字列型同士を結合するには、プラス記号（+）を使います。
#
# アスタリスク（*）を使って繰り返した文字列を取得できます。
#
# アスタリスクの左に繰り返したい文字列を、右に繰り返し回数を整数型で指定します

# %% [markdown]
# 文字列の結合
# ```
# ▶ 'Mt.' + 'Fuji'
# 'Mt.Fuji'
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# 文字列の繰り返し
# ```
# ▶ 'spam' * 5
# 'spamspamspamspamspam'
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### 1.4.4. インデックス表記
#
# 文字列のある位置を指定して1文字を取り出す機能です。

# %% [markdown]
# 文字列から1文字取り出し
# ```
# ▶ 'python'[1]
# 'y'
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# 文字列の先頭文字を0として数えた1の位置にある文字、 'y' が返されています。
#
# この位置をインデックスと呼びます。インデックスには負数も使えます。 以下の図のようになります。
#
# ![z31.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.4.5. スライス
# Pythonのスライスを使えば、 以下のように、2、3、4番目の文字 'tho' という文字列を取り出せます。
#
# ```
# ▶ 'python'[2:5]
# 'tho'
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# 取り出す文字列の位置は、整数型を2つ、コロン（:）で挟んで指定します。
#
# 指定する位置は、「（取り出す文字列に）含める文字の開始位置のインデックス」から「含めずに切り捨てる文字の開始位置のインデックス」と考えられます。
#
# 「インデックスが2の位置の 't' から始まり、インデックスが5の位置の 'n' 以降を切り捨てた」文字列、'tho' が返されます。

# %% [markdown]
# また先頭を含む文字列のスライスは、 以下のように切り出し、切り捨て位置を省略して指定します。
#
# ```
# ▶ 'python'[:3]
# 'pyt
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# さらに末尾を含む文字列のスライスは、 以下のように切り出し、切り捨て位置を省略して指定します。
#
# ```
# ▶ 'python'[4:]
# 'on'
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### 1.4.6. 文字列の長さ（len()関数）
#
# 文字列の長さを調べるには、 len() 関数を使います。 戻り値は整数型です。
#
# ```
# ▶ len('python')
# 6
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### 1.4.7. 文字列の有無（in演算子）
#
# 文字列中にある文字列が存在するかどうかを調べるには、 in 演算子を使います。
#
# 文字列中にある文字列が存在するかのチェック

# %% [markdown]
# ```
# ▶ 't' in 'python'
# True
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 'k' in 'python'
# False
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ```
# ▶ 'th' in 'python'
# True
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### 1.4.8. 文字列の分割（.split()メソッド）
#
# 文字列を分割するには、 .split() メソッドを使います。
#
# 分割したい文字列に対してメソッドを呼び出し、引数に**区切り文字（デリミタ）**を指定します。
#
# ハイフンで文字列を区切るには、 以下のようにします。
#
# **文字列の分割**
# ```
# ▶ 'pain-au-chocolat'.split('-')
# ['pain', 'au', 'chocolat']
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# ### 1.4.9. 区切り文字による文字列の結合（.join()メソッド）
#
# 文字列を区切り文字で結合するには、 .join() メソッドを使います。
#
# 区切り文字に対してメソッドを呼び出し、引数に結合したい文字列のリストを指定します（リスト 3.17）。
#
# 文字列の結合
#
# ```
# ▶ '-'.join(['pain', 'de', 'campagne'])
# 'pain-de-campagne'
# ```
# （コードを書いて実際に動かしてみよう）

# %% [markdown]
# # 2.Pythonのデータ型（コレクション編）
#
# Pythonのデータ型のうち、複数のデータ型をひとまとめにして扱えるコレクションを紹介します。

# %% [markdown]
# ## 2.1. はじめに
#
# コレクションにはいくつかの種類がありますが、今回はそのうちのリスト（list）について扱います。

# %% [markdown]
# ## 2.2. リスト（list）
#
# リストはコレクションの1つです。複数の型のデータをひとまとめにできます。
#
# リストを定義するには角括弧（[ ]）を使い、含める要素をカンマ（,）で区切ります。
#
# **リストの定義**
# ```
# ▶ ['spam', 'egg', 0.5]
# ['spam', 'egg', 0.5]
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 2.2.1 リストの結合、スライス
#
# リストも文字列と同様に、結合やスライスが使えます。

# %% [markdown]
# #### **リストの結合**
# ```
# ▶ ['spam', 'ham'] + ['egg']
# ['spam', 'ham', 'egg']
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# #### **リストの繰り返し**
# ```
# ▶ ['spam'] * 5
# ['spam', 'spam', 'spam', 'spam', 'spam']
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# #### **リストの0番目を取得する**
# ```
# ▶ ['spam', 'ham', 'egg'][0]
# 'spam'
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# #### **リストのスライス(1番目以降)**
# ```
# ▶ ['spam', 'ham', 'egg'][1:]
# ['ham', 'egg']
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# #### **リストの長さ**
# ```
# ▶ len(['spam', 'ham', 'egg'])
# 3
# ```
#
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# #### **リストに特定の文字列が含まれるか**
# ```
# ▶ 'ham' in ['spam', 'ham', 'egg']
# True
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 2.2.2. for文での利用
#
# リストは、for 文の繰り返し用変数として使えます。
#
#
# ```
# ▶ for animal in ['cat', 'dog', 'snake']:
# ▶   print(animal)
# cat
# dog
# snake
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 2.2.3. 要素の追加
#
# リストに要素を追加するには、 .append() メソッドを使います。 .append() メソッドはリストの末尾に要素を追加します。
#
# リストは変更可能なオブジェクトです。 .append() メソッドによって、 animals というリストの内容が変更されます。
#
# ```
# ▶ animals = ['cat', 'dog', 'snake']
# ▶ animals.append('elephant')
# ▶ animals
# ['cat', 'dog', 'snake', 'elephant']
# ```
# *（コードを書いて実際に確認してみよう）*

# %% [markdown]
# ### 2.2.4. リスト内包表記
#
# リスト内包表記はリストの定義方法の1つです。 比較的複雑なリストの定義を、シンプルに記述できます。
#
# for 文の例として animals リストから各文字列の長さの一覧を作ります。
#
# ・ 一般的なfor文
# ```
# ▶ ret = []
# ▶ for animal in animals:
# ▶   ret.append(len(animal))
# ▶ ret
# [3, 3, 5, 8]
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# 上の「一般的なfor文」の記述をリスト内包表記に置き換えると、以下のようになります
#
# ・ リスト内包表記
# ```
# ▶ [len(animal) for animal in animals]
# [3, 3, 5, 8]
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# 3行で記述していたコードが1行になりました。内包表記を使うと簡潔に記述できることがわかったと思います。 最初は見慣れないかもしれませんが、徐々に慣れていくと良いと思います。
#
# リストの定義時に、角括弧（[ ]）の内部に for を書きます。 for ＜変数名＞ in の部分は通常の for 文と同じです。
#
# for の左側でひとつひとつ取り出した要素（ここでは animal）を使い、リストの各要素を作ります。 リスト 4.6 の場合、 len(animal) の結果が各要素になります。
#
# リスト内包表記は、条件文や複数回のループ処理も記述できます。 複雑にしすぎると、かえって可読性を落としますので、ほどほどに使用することをおすすめします。複雑になりすぎる場合はループ処理で書きましょう。 リスト内包表記の仲間に、辞書(次回講義で説明)を生成する辞書内包表記や、セット(次回講義で説明)を生成するセット内包表記やジェネレータ式(講義では説明しません)などもあります。 内包表記はPythonの強力な機能の1つなのでぜひ覚えておくとよいでしょう。

# %% [markdown]
# 他にも役に立つ書き方があるので、Pythonのドキュメントを参考にしてください。
#
# リストの内包表記 https://docs.python.org/ja/3/tutorial/datastructures.html#list-comprehensions

# %% [markdown]
# ### 2.2.5. 複数変数への代入
#
# リストのようなシーケンス型から他のデータ型に値を代入する際、複数の変数への代入を一度に行えます。
#
# ・　シーケンス型から複数変数への代入
# ```
# ▶ dog, cat = ['wan', 'nyao']
# ▶ dog
# 'wan'
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# （続き）
# ```
# ▶ cat
# 'nyao'
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# 複数の変数への代入は、右辺が文字列やタプル（次回講義で説明）の場合でも可能です。

# %% [markdown]
# # 3.Pythonのデータ型（日付と時刻）
#
# Pythonには、年月日や時分秒といったデータを扱うために、dateやtimeという専用のデータ型が用意されています。日付を操作する型は「date型」です。date型には、その日が何曜日なのかを計算する処理が備わっています。また、「time型」は時間を表します。これらの型はよく似たデータ型ですので、「datetime」という名前のモジュール（*1） **太字**にまとめられています。
#
# **モジュールとは？**
#
# Ptthonには、プログラミングで多くの人々が共通して必要とする機能が、あらかじめ組み込まれています。日付の計算や、データの圧縮や解凍などたくさんの機能が備わっています。これらの機能はバラバラになっていると使いにくいので、機能ごとに**モジュール**という単位でまとまっています。
# モジュールを読み込むには、importという命令を使います。importの後にモジュール名を入力します。
#
# 実際に日付のデータ型や計算機能が備わっている「datetime」をインポートしてみましょう。
#
# ```
# ▶ import datetime
# ```
# （コードを書いて実際にモジュールを読み込んでみよう）

# %% [markdown]
# SHIFT+ENTERを押した後、何もメッセージが出なければ、モジュールの読み込みは成功です。

# %% [markdown]
# ## 3.1 日付データの作成
#
# 日付データを作るには、datetimeモジュールのdate型を使います。
#
# 型の名前であるdateの後に年、月、日とカンマ（,）続けで丸括弧の中に書いてみます。
#
# 実際に2030年6月30日を作ってみましょう。
#
# ```
# ▶　day = datetime.date(2030,6,30)
# ▶　print(day)
# 2030-06-30
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 3.1.1 曜日の確認
#
# date型には、その日が何曜日かを計算するweekdayという機能（メソッドと呼びます）が備わっています。この機能は、曜日を0から始まる数字で返し、0は月曜日を表しています。
#
# |戻り値|曜日|
# |---|---|
# |0|月曜|
# |1|火曜|
# |2|水曜|
# |3|木曜|
# |4|金曜|
# |5|土曜|
# |6|日曜|

# %% [markdown]
# さっそく、さきほど作った日付が何曜日なのか調べてみましょう。
# ```
# ▶ day.weekday()
# 6
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 3.1.2 今日を取得する
#
# date型には今日の日付を取得するtodayというメソッドが備わっています。
#
# 実際に今日を取得してみましょう。
#
# ```
# ▶ kyou = datetime.date.today()
# ▶ print(kyou)
# 2020-08-18
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 3.1.3 日付と時刻データの作成
#
# date型は日付だけをもつモノでした。今後は日付と時刻の両方を扱えるdatetime型を作ってみましょう。
#
# ```
# ▶　apollo_11 = datetime.datetime(1969,7,21,5,17,40)
# ▶　print(apollo_11)
# 1969-07-21 05:17:40
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 3.1.4 現在時刻を取得する
#
# date型には現在の時刻を取得するnowというメソッドが備わっています。
#
# 実際に現在の時刻を取得してみましょう。
#
# ```
# ▶ ima = datetime.datetime.now()
# ▶ print(ima)
# 2020-08-18 20:06:16.080858
# # ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 3.1.5 日付型の計算
#
# ある日付とある日付の間が何日あるかを計算するは、数字の計算と同じようにdate型どうして引き算をすれば求められます。
#
# 2020年1月1日（日付A）から2021年1月1日（日付B）まで何日あるのか実際に確認してみましょう。
#
# ```
# import datetime
# date_a = datetime.date(2020,1,1)
# date_b = datetime.date(2021,1,1)
# days_2020 = date_b - date_a
# days_2020
# ```
# （コードを書いて実際に確認してみよう）

# %%
import datetime
date_a = datetime.date(2020,1,1)
date_b = datetime.date(2021,1,1)
days_2020 = date_b - date_a
print(days_2020)

# %% [markdown]
# ### コーヒーブレイク：自分が何日生きたか計算しよう。
#
# 自分が今日まで何日生きたか計算して表示するプログラムを作ってみましょう。
#
# 上記の「3.1.5 日付型」の日付Aを今日にして、日付Bを自分の誕生日にすれば計算できます。
#
# やってみましょう。
#
# （ここに人生を計算するプログラムを書いみよう！）

# %%
import datetime
today =     # ここに今日を書こう
bitrhday =  # ここに誕生日を書こう
life = today - bitrhday
print(life)

# %% [markdown]
# # 4.コンピューターに選ばせる。
#
# 「2.Pythonのデータ型（コレクション編）」では、複数のデータ型をひとまとめにして扱えるコレクションを学びました。
#
# こういったコレクションから無作為に1つを選ぶことができれば、ゲームのようなものを作ることもできます。
# 例えばサイコロを振って1から6までの数字から1つを決めるのと同じことをPythonでプログラミングできます。
#
# randamモジュールにはchoiceというメソッドがあります。1から6までのリストを準備して、コンピューターから無作為に選ばせてみましょう。
#
# ```
# ▶ import random
# ▶ dice = [1,2,3,4,5,6]
# ▶ random.choice(dice)
# 3 # コンピューターによって1〜6を任意に選んで表示
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# randomモジュールには乱数を生成させるメソッドなどさまざまな機能が備わっています。

# %% [markdown]
# # 5.条件分岐と繰り返し
#
# これまではデータ型とその使い方を中心に学んできました。こうした知識も必要ですが、本格的にプログラミングができるようになるには、**条件分岐**と**繰り返し**の構文を取得する必要があります。

# %% [markdown]
# ## (A) 処理を繰り返す構文
#
# Pythonで繰り返しを行うにはfor文とWhile文のどちらかを使います。
#
# for（フォー）には、英語で「（目的地に）向かって」という意味があります。
#
# **for文**はリストの先頭要素から順に処理していくときに使います。

# %% [markdown]
# ![Screenshot 2020-08-18 17.55.25.png](data:image/png;base64,...)

# %% [markdown]
# while（ホワイル）には、英語で「〜の間ずっと」という意味があります。
#
# while文は一定の条件が成立する間はずっと処理を続けます。条件が成立しなくなると、処理の繰り返しが終わります。

# %% [markdown]
# ![Screenshot 2020-08-18 17.55.43.png](data:image/png;base64,...)

# %% [markdown]
# ## (B) 条件でその後の処理を変える構文

# %% [markdown]
# 条件に応じて後の処理を変える仕組みもあります。それがif文です。
#
# if（イフ）には、英語で「もし〜ならば」という意味があります。条件によってその後の処理を分けるときに使います。

# %% [markdown]
# ![Screenshot 2020-08-18 17.55.52.png](data:image/png;base64,...)

# %% [markdown]
# ## (C) エラー処理

# %% [markdown]
# 条件分岐と繰り返しの他に、Pythonには、プログラム中でエラーが発生したとき、その後の処理を切り替える仕組みがあります。
#
# 本来進むはずべきの道で何らかの事故が起こったときのやめの、巡回路を用意するようなイメージです。

# %% [markdown]
# ![Screenshot 2020-08-18 17.55.59.png](data:image/png;base64,...)

# %% [markdown]
# ## 5.1 for文
#
# 最初はfor文をおぼえましょう。リスト型をプログラムで使うにはかならず必要になります。
#
# 平成17年の東北地方6県の県庁所在地別の1世帯あたりの納豆購入金額の平均値を計算してみましょう。
#
# |東北地方|納豆購入金額|
# |---|---|
# |青森市|5,349円|
# |盛岡市|5,478円|
# |仙台市|5,344円|
# |秋田市|4,644円|
# |山形市|4,698円|
# |福島市|6,259円|

# %% [markdown]
# まずは県別のデータからリスを作成してみましょう。

# %% [markdown]
# ```
# ▶ list_tohoku = [5349,5478,5344,4644,4968,6259]
# ```
# （コードを書いて実際に確認してみよう）

# %%
list_tohoku = [5349,5478,5344,4644,4968,6259]

# %% [markdown]
# ### 5.2.1 for文でリストの中身を一括表示
#
# こんどはリストの中身を確認してみましょう。
#
# ```
# ▶ for val in list_tohoku:
# ▶   print(val)
# ```
# （コードを書いて実際に確認してみよう）

# %%
for val in list_tohoku:
  print(val)

# %% [markdown]
# ### 5.2.2 平均値を求める

# %% [markdown]
# 今回は平均値を求めるのが目的でした。
#
# 繰り返し変数valの値を加算して、最後にリスト長さで割れば平均が求められます。

# %% [markdown]
# ```
# ▶ avg_tohoku = 0
# ▶ for val in list_tohoku:
# ▶   avg_tohoku += val
# ▶ avg_tohoku /= len(list_tohoku)
# ▶ avg_tohoku
# 5340.333333333333
# ```
#
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ## 5.2 if文
#
# if文は、プログラムが動作している途中で、刻々と変わる条件に応じてその処理を振り分けるための構文です。

# %% [markdown]
# ### 5.2.1 真偽型とif文
#
# Pythonには、真（True）か偽（False）の2種類の値だけを持つ真偽値があります。この真偽値はブール型(bool型)というデータ型の一つとして定義されます。比較や論理演算の結果を表すために使われます。

# %% [markdown]
# ```
# ▶ 1 > 0
# True
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ```
# ▶ 1 < 0
# False
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# **今日は学校がある曜日か確認しよう。**
#
# 最初の方で学んだdate型の曜日から、今日は学校ある日なのか判定してみよう。
#
# まずは今日を取得してみます。

# %% [markdown]
# ```
# ▶ import datetime
# ▶ today = datetime.date.today()
# ▶ print(today)
# 2020-08-18
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# 続いて曜日をみてみましょう。0〜6まで月か水木金土日という値が返ってきます。

# %% [markdown]
# ```
# ▶ today.weekday()
# 2
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# 土曜日までかという判定をしてみましょう。

# %% [markdown]
# ```
# ▶today.weekday() <= 6
# True
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 5.2.2　条件によって処理を変更

# %% [markdown]
# 実際にif文で処理を書いてみましょう。
#
# 学校がある日は頑張ろうみたいな感じにしてみます。

# %% [markdown]
# ```
# ▶　if today.weekday() < 6 :
# ▶　  print('勉強がんばろう')
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# **判定にはさまざまなモノがあります。まとめて覚えてみましょう。**

# %% [markdown]
# #### 5.2.2(a) 比較演算子
#
# ```
# ▶ a = 11
# ▶ if a > 10:
# ▶   print("OK")
# OK
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# |演算子|記述|説明|
# |---|---|---|
# |==|x == y|xとyは等しい
# |!=|x != y|xとyは等しくない
# |<|x< y|xはyより小さい
# |<=|x <= y|xはyより小さいか等しい
# |>|x > y|xはyより大きい
# |>=|x >= y|xはyより大きいか等しい

# %% [markdown]
# #### 5.2.2(b) in演算子
#
# リストの要素かどうか、文字列中に含まれているかどうかを調べるときに in 演算子を使う。含まれている場合は真(True)を、含まれていない場合は偽（False）を返す。

# %% [markdown]
# ```
# ▶ if 'a' in ['a','b','c']:
# ▶  print("OK")
# OK
# ```

# %% [markdown]
# #### 5.2.2(c) 論理演算子
#
# ```
# ▶ a = 11
# ▶ b = 16
# ▶ if a > 10 and b < 15:
# ▶   print("OK")
# OK
# ```

# %% [markdown]
# |演算子|記述|説明|
# |---|---|---|
# |and|x and y|xとyの両方が真(True)だったら真(True)
# |or|x or y|xとyのどちらかが真(True)だったら真(True)
# |not|not x|xが真(True)だったら偽(False)、偽(False)だったら真(True)

# %% [markdown]
# 5.2.2(d) None と　is 演算子

# %% [markdown]
# ```
# ▶ x = None
# ▶ if x is None:
# ▶   print("OK")
# OK
# ```

# %% [markdown]
# ```
# ▶ x = None
# ▶ if x is not None:
# ▶   print("OK")
# ```

# %% [markdown]
# ### 5.2.3 elseによる分岐処理
#
# 日曜日の時は何も表示されないので、動いているのかわからなくなってしまいます。
#
# 日曜は休む宣言をしてみましょう。

# %% [markdown]
# ```
# ▶　if today.weekday() < 6 :
# ▶　  print('勉強がんばろう')
# ▶　else :
# ▶　  print('ゆっくり休もう')
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 5.2.4 if 〜 elif 〜 else　文による分岐処理
#
# 週末（土曜日）になると体力が心配ですよね。土曜日だけペースを落とすようしましょう。
#
# elifを使うともう少し細かい条件文ができます。

# %% [markdown]
# ```
# ▶　if today.weekday() < 5 :
# ▶　  print('勉強がんばろう')
# ▶　elif today.weekday() == 5 :
# ▶　  print('ゆっくりがんばろう')
# ▶　else :
# ▶　  print('ゆっくり休もう')
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ## 5.3 while文
#
# for文は、リストのように個数が決まっているデータを順々にアクセスする場合に便利でした。
#
# while文も、基本的はfor文のように繰り返す処理を実行スル構文ですが、繰り返し処理を回し続けるか、ストップするかを条件式できめることができます。

# %% [markdown]
# ### 5.3.1 条件が成立している間は繰り返す

# %% [markdown]
# 数が決まっていない例として、乱数を使ってみましょう。
#
# randintを使うと任意の範囲でランダムな整数を受け取ることができ真ます。

# %% [markdown]
# ```
# ▶ import random
# ▶ random.randint(0,9)
# 7
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# つづいて、while文を使って、乱数で4ができるまで繰り返してみましょう。
#
# while文の中に条件式を書きます。

# %% [markdown]
# ```
# ▶ rand_num = 0
# ▶ while rand_num != 4:
# ▶   rand_num = random.randint(0,9)
# ▶   print(rand_num)
# 2
# 6
# 7
# 9
# 4
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ### 5.3.2 continueとbreak

# %% [markdown]
# ```
# ▶ while True:
# ▶   rand_num = random.randint(0,9)
# ▶   print(rand_num)
# ▶   if rand_num != 4:
# ▶     continue
# ▶   else:
# ▶     break
# 1
# 8
# 5
# 8
# 6
# 4
# ```
# （コードを書いて実際に確認してみよう）

# %% [markdown]
# ## 5.4 エラー処理
#
# Pythonは処理ができないコードを受け取るとエラーを発生します。
#
# そういった時にはエラー処理を実行することができます。
#
# とても重要な処理ですが、発展的な内容なのでこの時点では「エラー処理を実行できる」ということだけ覚えておいて下さい。
#
# 今後の講義で詳しく説明します。

# %% [markdown]
# # 6. Pythonお薦め本（阿部個人の感想）
#
# （初心者向け）
#
# * [Pythonスタートブック(増補改訂版)@辻真吾](https://www.amazon.co.jp/dp/4774196436)
# * [みんなのPython 第4版@柴田淳](https://www.amazon.co.jp/dp/479738946X)
# * 【Python試験対策用】[Python 3スキルアップ教科書@辻真吾](https://www.amazon.co.jp/dp/4297107562)
#
# （データ分析者向け）
#
# * [改訂版 PythonユーザのためのJupyter実践入門@池内孝啓](https://www.amazon.co.jp/dp/4297115689)
# * [Python実践データ分析100本ノック@下山輝昌](https://www.amazon.co.jp/dp/4798058750)
#
# （時短好き向け）
# * [退屈なことはPythonにやらせよう ―ノンプログラマーにもできる自動化処理プログラミング](https://www.amazon.co.jp/dp/487311778X/)
#
#
# （PythonによるWebアプリケーション）
#
# *　[現場で使える Django の教科書《基礎編》@横瀬明仁](https://www.amazon.co.jp/dp/4802094744)

# %% [markdown]
# # 7.直近のPythonオンライン勉強会
#
# * 2020年8月28日〜29日 [PyCon JP 2020](https://pycon.jp/2020)
#
# * 2020年8月28日 [みんなのPython勉強会#61](https://startpython.connpass.com/event/186016/)

# %% [markdown]
# # 8.その他勉強会の案内
#
# * [connpass](https://connpass.com)サイトの紹介
# * [VUCA labo #005 中川敬文さん「地方から考えるこれからのまちづくり」](https://vucalabo.connpass.com/event/185379/)
# * [フィンテックエンジニアエンジニア養成勉強会#10 DeFi（分散型金融）の現状とこれから](https://fintech-engineer.connpass.com/event/186127/)
