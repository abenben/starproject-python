# %% [markdown]
# <a href="https://colab.research.google.com/github/abenben/starproject-python/blob/master/slide09-base/seaborn-08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 3.8: ペアグリッドの活用(seaborn)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 3.8.1　PairGrid クラスによるグラフの描画

tips = sns.load_dataset("tips")
sns.PairGrid(tips)

# %%
# 3.8.2　散布図を描画

import matplotlib.pyplot as plt

pair_grid = sns.PairGrid(tips)
pair_grid.map(plt.scatter)

# %%
# 3.8.3　色分けした散布図行列の描画

sns.PairGrid(tips, hue="smoker").map(plt.scatter)

# %%
# 3.8.4　異なる種類のグラフを描画

pair_grid_kinds = sns.PairGrid(tips, hue="smoker")
pair_grid_kinds.map_upper(sns.regplot)
pair_grid_kinds.map_diag(plt.hist)
pair_grid_kinds.map_lower(sns.kdeplot)

# %%
# 3.8.5　DataFrame のデータ型を参照

tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# 3.8.6　描画対象の列を指定して描画

sns.PairGrid(tips, vars=["total_bill", "tip", "smoker"]).map(sns.scatterplot)

# %%
# 3.8.7　X 値、Y 値の列を指定して描画

sns.PairGrid(tips, x_vars=["total_bill", "size"], y_vars=["tip"]).map(sns.scatterplot)
