# %% [markdown]
# <a href="https://colab.research.google.com/github/abenben/starproject-python/blob/master/slide09-base/seaborn-09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 3.9: ジョイントグリッドの活用(seaborn)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 3.9.1　JointGrid クラスによるグラフの描画

tips = sns.load_dataset("tips")
sns.JointGrid(data=tips, x="total_bill", y="tip")

# %%
# 3.9.2　散布図の辺にグラフを追加

joint_grid = sns.JointGrid(data=tips, x="total_bill", y="tip")
joint_grid.plot(plt.scatter, sns.histplot)

# %%
# 3.9.3　plot_joint() メソッドと plot_marginals() メソッドを利用したグラフの描画

joint_grid = sns.JointGrid(data=tips, x="total_bill", y="tip")
joint_grid.plot_joint(plt.scatter)
joint_grid.plot_marginals(sns.histplot)

# %%
# 3.9.4　Matplotlib のメソッドを利用したグラフの描画

joint_grid_ax = sns.JointGrid(data=tips, x="total_bill", y="tip")
joint_grid_ax.plot_joint(sns.regplot)
joint_grid_ax.ax_marg_x.hist(tips["total_bill"])
joint_grid_ax.ax_marg_y.boxplot(tips["tip"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f64eaa6f320>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f64eaaa31d0>,
#   <matplotlib.lines.Line2D at 0x7f64e9da1fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f64eaf0a940>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f64e9535dd8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f64eaaa3710>,
#   <matplotlib.lines.Line2D at 0x7f64eaaa3f98>]}
